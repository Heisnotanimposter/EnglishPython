# %% [markdown]
# <a href="https://colab.research.google.com/github/Heisnotanimposter/EnglishPython/blob/main/multi_lang_interpreter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import pipeline, AutoTokenizer, AutoModelForSeq2SeqLM

# 1. Load Pre-trained Model and Tokenizer
model_name = "facebook/m2m100_418M"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

# 2. Create Translation Pipeline
translator = pipeline("translation", model=model, tokenizer=tokenizer,
                      num_beams=5, temperature=0.7, max_length=128)  # Adjust parameters as needed

# 3. Perform Translation to Multiple Target Languages
text_to_translate = input("Enter the english text you want to translate: ")
#source_language = input("Enter the source language code (e.g., 'en'): ")
source_language = "en"
target_languages = ["fr", "es", "de", "it", "pt", "ru", "zh", "ja", "ko", "ar", "hi"]

for target_language in target_languages:
  translated_text = translator(text_to_translate, src_lang=source_language, tgt_lang=target_language)
  print(f"Translation to {target_language}: {translated_text[0]['translation_text']}")
# Out:
# tokenizer_config.json:   0%|          | 0.00/298 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/908 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/3.71M [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/1.14k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.94G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/233 [00:00<?, ?B/s]
# Enter the english text you want to translate: Hello! It's been a long time. How have you been?
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:540: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.7` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# Translation to fr: Bonjour, il y a longtemps, comment as-tu été ?
# Translation to es: Hace mucho tiempo, ¿cómo te has ido?
# Translation to de: Hallo, es ist eine lange Zeit vergangen. wie warst du?
# Translation to it: Ciao, è stato un po’ di tempo, come sei andato?
# Translation to pt: Olá! há muito tempo. como você foi?
# Translation to ru: Долгое время! как вы себя чувствуете?
# Translation to zh: 你好!很久了!你怎么了?
# Translation to ja: こんにちは!久しぶりです!どうでしたか?
# Translation to ko: 안녕하세요 오랜만에 왔는데 어떻게 되셨나요?
# Translation to ar: ههههههههههههههههههههههههههههه
# Translation to hi: बहुत समय बीत चुका है. तुम कैसे हो?
